# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sal=pd.read_csv('G:\Data Analysis\Salary Data_Sharath.csv')

# %%
print (str(sal.shape[0])+"  "+str(sal.shape[1]))
# Out:
# 3498  22

# %%
sal.head()
# Out:
#    Registration Number    CTC      Joining_date      Leaving_date  \
# 0               432376   4.20  01-06-2012 00:00           present
# 1               432383   5.00  01-09-2013 00:00           present
# 2               432390   3.25  01-06-2014 00:00           present
# 3               432397  11.00  01-07-2011 00:00           present
# 4               432404   2.00  01-03-2014 00:00  01-03-2015 00:00
#
#                        Role    JobCity Gender               DOB  10percentage  \
# 0   senior quality engineer  Bangalore      f  19-02-1990 00:00          84.3
# 1         assistant manager     Indore      m  04-10-1989 00:00          85.4
# 2          systems engineer    Chennai      f  03-08-1992 00:00          85.0
# 3  senior software engineer    Gurgaon      m  05-12-1989 00:00          85.6
# 4                       get    Manesar      m  27-02-1991 00:00           NaN
#
#                           10board  ...                             12board  \
# ...

# %%
sal.describe()
# Out:
#        Registration Number          CTC  10percentage  12graduation  \
# count          3498.000000  3498.000000   3398.000000   3498.000000
# mean         444615.500000     3.082258     77.936004   2008.085477
# std            7069.509636     2.203398      9.839156      1.657165
# min          432376.000000     0.350000     43.000000   1995.000000
# 25%          438495.750000     1.800000     72.000000   2007.000000
# 50%          444615.500000     3.000000     79.000000   2008.000000
# 75%          450735.250000     3.700000     85.745000   2009.000000
# max          456855.000000    40.000000     97.760000   2013.000000
#
#        12percentage     CollegeID  CollegeTier   collegeGPA  CollegeCityID  \
# count   3442.000000   3498.000000  3448.000000  3498.000000    3498.000000
# mean      74.403451   5301.473699     1.926624    71.469777    5301.473699
# std       10.938945   2780.436629     0.260790     8.273036    2780.436629
# ...

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sal=pd.read_csv('G:\Data Analysis\Salary Data_Sharath.csv')
sns.distplot(sal.CollegeTier.dropna(),kde=False)

# %%
sal=pd.read_csv('G:\Data Analysis\Salary Data_Sharath.csv')
sal.head()
# Out:
#    Registration Number    CTC      Joining_date      Leaving_date  \
# 0               432376   4.20  01-06-2012 00:00           present
# 1               432383   5.00  01-09-2013 00:00           present
# 2               432390   3.25  01-06-2014 00:00           present
# 3               432397  11.00  01-07-2011 00:00           present
# 4               432404   2.00  01-03-2014 00:00  01-03-2015 00:00
#
#                        Role    JobCity Gender               DOB  \
# 0   senior quality engineer  Bangalore      f  19-02-1990 00:00
# 1         assistant manager     Indore      m  04-10-1989 00:00
# 2          systems engineer    Chennai      f  03-08-1992 00:00
# 3  senior software engineer    Gurgaon      m  05-12-1989 00:00
# 4                       get    Manesar      m  27-02-1991 00:00
#
#    t10percentage                        t10board  ...  \
# 0           84.3  board ofsecondary education,ap  ...
# 1           85.4                            cbse  ...
# ...

# %%
sns.distplot(sal.t10percentage.dropna(),kde=False)

# %%
sns.distplot(sal.t12percentage.dropna(),kde=False)

# %%
sal.describe()
plt.figure(figsize=(13, 8))
sns.countplot(sal.JobCity.dropna(),order=sal.JobCity.value_counts().iloc[:40].index);
plt.xticks(rotation=90);

# %%
sal.describe()
plt.figure(figsize=(13, 8))
sns.countplot(sal.t10board.dropna(),order=sal.t10board.value_counts().iloc[:40].index);
plt.xticks(rotation=90);

# %%
sal.describe()
plt.figure(figsize=(13, 8))
sns.countplot(sal.t12board.dropna(),order=sal.t12board.value_counts().iloc[:40].index);
plt.xticks(rotation=90);
